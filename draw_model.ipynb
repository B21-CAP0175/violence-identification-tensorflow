# %%
# !pip install pydot
# !pip install graphviz
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#from keras_visualizer import visualizer
# Out:
# Requirement already satisfied: pydot in c:\users\igana\anaconda3\envs\tf_gpu\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\igana\anaconda3\envs\tf_gpu\lib\site-packages (from pydot) (2.4.7)
# Requirement already satisfied: graphviz in c:\users\igana\anaconda3\envs\tf_gpu\lib\site-packages (0.16)

# %%
SAVED_MODEL_PATH = "training_mix_forthesecondtime.h5"

loaded=tf.keras.models.load_model(SAVED_MODEL_PATH)

dot_img_file = 'model_vis.png'
tf.keras.utils.plot_model(loaded, to_file=dot_img_file, show_shapes=True)
